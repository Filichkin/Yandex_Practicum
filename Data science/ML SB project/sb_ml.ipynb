# %% [markdown]
# <h1>HR аналитика<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задача-1:-предсказание-уровня-удовлетворённости-сотрудника" data-toc-modified-id="Задача-1:-предсказание-уровня-удовлетворённости-сотрудника-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задача 1: предсказание уровня удовлетворённости сотрудника</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-загрузке-данных" data-toc-modified-id="Вывод-по-загрузке-данных-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Вывод по загрузке данных</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-предобработке-данных" data-toc-modified-id="Вывод-по-предобработке-данных-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Вывод по предобработке данных</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Датафрейм-train_job_satisfaction_rate" data-toc-modified-id="Датафрейм-train_job_satisfaction_rate-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Датафрейм train_job_satisfaction_rate</a></span></li><li><span><a href="#Датафрейм-test_features" data-toc-modified-id="Датафрейм-test_features-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Датафрейм test_features</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Функция-расчета-метрики-SMAPE" data-toc-modified-id="Функция-расчета-метрики-SMAPE-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Функция расчета метрики SMAPE</a></span></li><li><span><a href="#Расчет-метрики-SMAPE-на-тестовой-выборке" data-toc-modified-id="Расчет-метрики-SMAPE-на-тестовой-выборке-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Расчет метрики SMAPE на тестовой выборке</a></span></li><li><span><a href="#Вывод-по-задаче-1" data-toc-modified-id="Вывод-по-задаче-1-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Вывод по задаче 1</a></span></li></ul></li></ul></li><li><span><a href="#Задача-2:-предсказание-увольнения-сотрудника-из-компании" data-toc-modified-id="Задача-2:-предсказание-увольнения-сотрудника-из-компании-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задача 2: предсказание увольнения сотрудника из компании</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-загрузке-данных" data-toc-modified-id="Вывод-по-загрузке-данных-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Вывод по загрузке данных</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-предобработке-данных" data-toc-modified-id="Вывод-по-предобработке-данных-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Вывод по предобработке данных</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Датафрейм-train_quit" data-toc-modified-id="Датафрейм-train_quit-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Датафрейм train_quit</a></span></li><li><span><a href="#Датафрейм-test_features" data-toc-modified-id="Датафрейм-test_features-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Датафрейм test_features</a></span></li><li><span><a href="#Портрет-«уволившегося-сотрудника»" data-toc-modified-id="Портрет-«уволившегося-сотрудника»-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Портрет «уволившегося сотрудника»</a></span></li><li><span><a href="#Уровень-удовлетворённости-сотрудника-работой" data-toc-modified-id="Уровень-удовлетворённости-сотрудника-работой-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Уровень удовлетворённости сотрудника работой</a></span></li><li><span><a href="#Общий-вывод-по-исследовательскому-анализу-данных" data-toc-modified-id="Общий-вывод-по-исследовательскому-анализу-данных-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>Общий вывод по исследовательскому анализу данных</a></span></li></ul></li><li><span><a href="#Добавление-нового-входного-признака" data-toc-modified-id="Добавление-нового-входного-признака-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Добавление нового входного признака</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#Расчет-метрики-тестовой-выборки" data-toc-modified-id="Расчет-метрики-тестовой-выборки-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Расчет метрики тестовой выборки</a></span></li><li><span><a href="#Анализ-моделей-и-признаков" data-toc-modified-id="Анализ-моделей-и-признаков-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Анализ моделей и признаков</a></span></li><li><span><a href="#Вывод-по-подбору-и-обучению-моделей" data-toc-modified-id="Вывод-по-подбору-и-обучению-моделей-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Вывод по подбору и обучению моделей</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Рекомендации-для-бизнеса" data-toc-modified-id="Рекомендации-для-бизнеса-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Рекомендации для бизнеса</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# Позади много уроков и заданий, и закрепить свои знания, как обычно, вы сможете в самостоятельном проекте. Это непростой проект, в котором от вас потребуется больше самостоятельности. Этапы работы описаны кратко, и вам понадобится декомпозировать задачи, то есть разделить их на более мелкие. Опирайтесь на знания об этапах анализа данных и машинного обучения из прошлых курсов.
#
# Перейдём к задаче. HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
#
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
#
# У вас будет несколько задач. Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
#
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# Ваша вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# Теперь расскажем подробнее о задачах.
#
# **Задача 1: предсказание уровня удовлетворённости сотрудника**
#
# Для этой задачи заказчик предоставил данные с признаками:
# - id — уникальный идентификатор сотрудника;
# - dept — отдел, в котором работает сотрудник;
# - level — уровень занимаемой должности;
# - workload — уровень загруженности сотрудника;
# - employment_years — длительность работы в компании (в годах);
# - last_year_promo — показывает, было ли повышение за последний год;
# - last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# - salary — ежемесячная зарплата сотрудника;
# - job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак.
#
# Шаг 1. Загрузка данных
#
# Загрузите файлы с данными:
#
# Тренировочная выборка:
# train_job_satisfaction_rate.csv (https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv)
#
# Входные признаки тестовой выборки:
# test_features.csv (https://code.s3.yandex.net/datasets/test_features.csv)
#
# Целевой признак тестовой выборки:
# test_target_job_satisfaction_rate.csv (https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv)
#
# Шаг 2. Предобработка данных
#
# Изучите данные и сделайте выводы. При необходимости выполните предобработку. Если есть пропуски, заполните их в пайплайне.
#
# Шаг 3. Исследовательский анализ данных
# Исследуйте все признаки и сделайте выводы о том, как их нужно подготовить.
#
# Шаг 4. Подготовка данных
# Подготовку признаков выполните в пайплайне, дополнив пайплайн шага предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.
#
# Шаг 5. Обучение моделей
# Обучите как минимум две модели. Возьмите одну линейную модель, а в качестве второй — дерево решений. Подберите гиперпараметры как минимум для одной модели с помощью одного из известных вам инструментов.
#
# Выберите лучшую модель и проверьте её качество. Выбор делайте на основе новой метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).
#
# Метрика SMAPE вычисляется так:
#
# SMAPE=100∑=1∣−^∣(∣∣+∣^∣)/2,SMAPE=n100 ∑i=1n (∣yi ∣+∣y^ i ∣)/2∣yi −yi ^ ∣,
# где:
# - yi — фактическое значение целевого признака для объекта с порядковым номером i в выборке;
# - ^yi ^ — предсказанное значение целевого признака для объекта с порядковым номером i в выборке;
# - n — количество объектов в выборке;
# - ∑=1∑i=1n — сумма значений, полученная в результате операций, которые следуют за этим знаком, для всех объектов с порядковым номером от i до n в выборке.
#
# Напишите функцию, которая принимает на вход массивы NumPy или объекты Series в pandas и возвращает значение метрики SMAPE. Используйте эту метрику при подборе гиперпараметров и оценке качества моделей.
# Критерий успеха: SMAPE ≤15 на тестовой выборке.
# В решении сохраните работу со всеми моделями, которые вы пробовали. Сделайте выводы.
#
# Шаг 6. Оформление выводов
# Сделайте промежуточные выводы о том, какая модель справилась лучше и почему.
#
# **Задача 2: предсказание увольнения сотрудника из компании**
#
# Для этой задачи вы можете использовать те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это quit — увольнение сотрудника из компании.
#
# Шаг 1. Загрузка данных
# Загрузите данные из файлов:
# Тренировочная выборка:
#
# train_quit.csv (https://code.s3.yandex.net/datasets/train_quit.csv)
#
# Входные признаки тестовой выборки те же, что и в прошлой задаче:
# test_features.csv (https://code.s3.yandex.net/datasets/test_features.csv)
# Целевой признак тестовой выборки:
# test_target_quit.csv (https://code.s3.yandex.net/datasets/test_target_quit.csv)
#
# Шаг 2. Предобработка данных
# Изучите данные и при необходимости выполните предобработку. Если есть пропуски, заполните их в пайплайне.
#
# Шаг 3. Исследовательский анализ данных
#
# 3.1. Проведите исследовательский анализ данных.
#
# 3.2. Составьте портрет «уволившегося сотрудника». Например, можно узнать, в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также можно сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.
#
# 3.3. Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверьте это утверждение: визуализируйте и сравните распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используйте данные с обоими целевыми признаками тестовой выборки.
#
# Шаг 4. Добавление нового входного признака
# Допустим, job_satisfaction_rate и quit действительно связаны и вы получили необходимое значение метрики в первой задаче. Тогда добавьте job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.
#
# Шаг 5. Подготовка данных
# Подготовьте признаки так же, как и в первой задаче: выполните подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.
#
# Шаг 6. Обучение модели
# Обучите как минимум три модели. Как минимум для двух из них подберите гиперпараметры. Проверьте качество лучшей модели.
# Метрика оценки качества в этой задаче — ROC-AUC. Критерий успеха: ROC-AUC ≥0.91 на тестовой выборке. Напомним: отбор признаков часто помогает улучшить метрику.
#
# Шаг 7. Выводы
# Сделайте промежуточные выводы о том, какая модель справилась лучше и почему.
# Общий вывод
# Сформулируйте общий вывод:
#  • опишите задачу;
#  • опишите все этапы работы;
#  • добавьте выводы и дополнительные предложения для бизнеса.
#
# Оформление
# Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Используйте форматирование и заголовки.
# Как будут проверять мой проект
# Ваш проект будут оценивать по критериям. Прежде чем решать кейс, внимательно изучите их.
# На что обращают внимание при проверке проектов:
#  • как вы описываете найденные в данных проблемы;
#  • какие методы построения графиков применяете для исследовательского анализа;
#  • какие методы предобработки и подготовки данных применяете и как обосновываете принятое решение;
#  • используете ли пайплайны и автоматизируете ли повторяющиеся шаги;
#  • какие ML-решения вы реализуете;
#  • как выбираете и объясняете лучшее ML-решение;
#  • как вы интерпретируете результаты работы лучшей модели;
#  • соблюдаете ли структуру проекта и поддерживаете ли аккуратность кода;
#  • какие выводы делаете для бизнеса;
#  • оставляете ли комментарии к шагам.
# Успехов!

# %% [markdown]
# ## Задача 1: предсказание уровня удовлетворённости сотрудника

# %% [markdown]
# ### Загрузка данных

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import warnings
warnings.simplefilter("ignore")

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest


# загружаем класс pipeline
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
    MinMaxScaler,
    RobustScaler,
    LabelEncoder
)
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем функцию для работы с метриками
from sklearn.metrics import (
    roc_auc_score,
    confusion_matrix,
    make_scorer
)

# загружаем нужные модели
from sklearn.linear_model import (
    LogisticRegression,
    LinearRegression,
    Lasso,
    Ridge
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.svm import SVC, SVR

from scipy import stats as st

try:
    import phik
except:
    # !pip install phik

try:
    import shap
except:
    # !pip install shap
    
import phik
from phik import phik_matrix
from phik.report import plot_correlation_matrix

# %%
print(sklearn.__version__)
print(pd.__version__)
print(shap.__version__)
print(phik.__version__)
# Out:
# 1.1.3
# 2.0.1
# 0.45.0
# 0.12.4

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# **Тренировочная выборка:**

# %%
file_train_l = '/Users/alexfil/Desktop/Practicum/Проекты/ML SB/train_job_satisfaction_rate.csv'
file_train_y = 'https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv'

# %%
try:
    train_job_satisfaction_rate = pd.read_csv(file_train_l, decimal='.', sep=',') 
except:
    train_job_satisfaction_rate = pd.read_csv(file_train_y, decimal='.', sep=',')

# %%
display(train_job_satisfaction_rate.head(5))
display(train_job_satisfaction_rate.shape)
# Out:
#        id        dept   level workload  employment_years last_year_promo
# 0  155278       sales  junior   medium                 2              no  \
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20
# (4000, 10)

# %% [markdown]
# **Входные признаки тестовой выборки:**

# %%
file_test_l = '/Users/alexfil/Desktop/Practicum/Проекты/ML SB/test_features.csv'
file_test_y = 'https://code.s3.yandex.net/datasets/test_features.csv'

# %%
try:
    test_features = pd.read_csv(file_test_l, decimal='.', sep=',') 
except:
    test_features = pd.read_csv(file_test_y, decimal='.', sep=',')

# %%
display(test_features.head(5))
display(test_features.shape)
# Out:
#        id       dept   level workload  employment_years last_year_promo
# 0  485046  marketing  junior   medium                 2              no  \
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
# (2000, 9)

# %% [markdown]
# **Целевой признак тестовой выборки:**

# %%
file_target_l = '/Users/alexfil/Desktop/Practicum/Проекты/ML SB/test_target_job_satisfaction_rate.csv'
file_target_y = 'https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv'

# %%
try:
    test_target_job_satisfaction_rate = pd.read_csv(file_target_l, decimal='.', sep=',') 
except:
    test_target_job_satisfaction_rate = pd.read_csv(file_target_y, decimal='.', sep=',')

# %%
display(test_target_job_satisfaction_rate.head(5))
display(test_target_job_satisfaction_rate.shape)
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08
# (2000, 2)

# %% [markdown]
# #### Вывод по загрузке данных
#
# 1. Загружено 3 датафрейма с разной размерностью отображенной с помощью shape
# 2. При загрузке использованн разделитель значений — запятая, а разделитель десятичных значений — запятая

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# **Поиск дубликатов**

# %%
display(train_job_satisfaction_rate.duplicated().sum(),
       test_features.duplicated().sum(),
       test_target_job_satisfaction_rate.duplicated().sum()
       )
# Out:
# 0
# 0
# 0

# %% [markdown]
# Оценим наличие неявных дубликатов:

# %%
cat_col_names_train = train_job_satisfaction_rate.select_dtypes(exclude='number').columns.tolist()

# %%
for c in cat_col_names_train:
    print(f'Категория: {c}\n\n', train_job_satisfaction_rate[c].unique(), '\n')
# Out:
# Категория: dept
#
#  ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
#
# Категория: level
#
#  ['junior' 'middle' 'sinior' nan]
#
# Категория: workload
#
#  ['medium' 'high' 'low']
#
# Категория: last_year_promo
#
#  ['no' 'yes']
#
# Категория: last_year_violations
#
#  ['no' 'yes']

# %%
cat_col_names_test = test_features.select_dtypes(exclude='number').columns.tolist()

# %%
cat_col_names_test
# Out:
# ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
for c in cat_col_names_test:
    print(f'Категория: {c}\n\n', test_features[c].unique(), '\n')
# Out:
# Категория: dept
#
#  ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
#
# Категория: level
#
#  ['junior' 'middle' 'sinior' nan]
#
# Категория: workload
#
#  ['medium' 'low' 'high' ' ']
#
# Категория: last_year_promo
#
#  ['no' 'yes']
#
# Категория: last_year_violations
#
#  ['no' 'yes']

# %% [markdown]
# **Вывод:** дубликатов нет

# %% [markdown]
# **Анализ типов данных и пропущенных значений**

# %%
train_job_satisfaction_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %%
train_job_satisfaction_rate.isna().sum()
# Out:
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %%
train_job_satisfaction_rate['dept'].value_counts()
# Out:
# dept
# sales         1512
# technology     866
# purchasing     610
# marketing      550
# hr             456
# Name: count, dtype: int64

# %%
train_job_satisfaction_rate['level'].value_counts()
# Out:
# level
# junior    1894
# middle    1744
# sinior     358
# Name: count, dtype: int64

# %% [markdown]
# Датафрейм train_job_satisfaction_rate содержит пропуски в колонках 'dept и 'level', которые в дальнейшем целесообразно заполнить в пайплане, используя **strategy='most_frequent'**

# %%
test_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %% [markdown]
# Датафрейм test_features содержит пропуски в колонках 'dept и 'level', которые в дальнейшем целесообразно заполнить в пайплане, используя strategy='most_frequent'

# %%
test_target_job_satisfaction_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# #### Вывод по предобработке данных
#
# 1. Типы данных в датефреймах соответствуют описанию
# 2. Датафреймы train_job_satisfaction_rate и test_features содержат пропуски в колонках 'dept и 'level', которые в дальнейшем целесообразно заполнить в пайплане, используя strategy='most_frequent'

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Датафрейм train_job_satisfaction_rate

# %%
cat_col_names_train
# Out:
# ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
num_col_names_train = \
    train_job_satisfaction_rate.loc[:, ~train_job_satisfaction_rate.columns.isin(['id'])]. \
        select_dtypes(include='number').columns.tolist()

# %%
num_col_names_train
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %% [markdown]
# **Количественные признаки:**

# %%
train_job_satisfaction_rate[num_col_names_train].describe().T.round(2)
# Out:
#                         count      mean       std       min       25%
# employment_years       4000.0      3.72      2.54      1.00      2.00  \
# supervisor_evaluation  4000.0      3.48      1.01      1.00      3.00
# salary                 4000.0  33926.70  14900.70  12000.00  22800.00
# job_satisfaction_rate  4000.0      0.53      0.23      0.03      0.36
#
#                             50%       75%      max
# employment_years           3.00      6.00     10.0
# supervisor_evaluation      4.00      4.00      5.0
# salary                 30000.00  43200.00  98400.0
# job_satisfaction_rate      0.56      0.71      1.0

# %% [markdown]
# **employment_years:**
# - среднее значение 3.72
# - медиана 3.00
#
# **supervisor_evaluation:**
# - среднее значение 3.48
# - медиана 4.00
#
# **salary:**
# - среднее значение 33,926.70
# - медиана 30,000.00
# - наличие выбросов, вероятно это категория sinior
#
# **job_satisfaction_rate:**
# - среднее значение 0.53
# - медиана 0.56

# %%
def hist_plot(df, count_list, figsize):
    row = math.ceil(len(count_list))
    fig, axes = plt.subplots(row, 2, figsize=(12, figsize))
    plt.suptitle('Распределение по количественным признакам',
                 x=0.5,
                 y=0.9,
                 fontsize=12,
                 fontweight='bold')    
    for i, j in enumerate(count_list):
        sns.histplot(data = df, x=j, ax=axes[i, 0],
                     kde=True,
                     line_kws = {'linestyle':'dashed',
                                 'linewidth':'1'},
                     color='#9BCD9B')
        sns.boxplot(data = df, x=j, ax=axes[i, 1],
                     color='#9BCD9B',
                     linewidth=0.5,
                     width=0.5,
                     medianprops={"color": "r", "linewidth": 1})

# %%
hist_plot(train_job_satisfaction_rate, num_col_names_train, 16)

# %%
cat_col_names_train = train_job_satisfaction_rate.select_dtypes(exclude='number').columns.tolist()

# %% [markdown]
# **Категоральные признаки:**

# %%
def cat_plot(df, kat_list):
    row = math.ceil(len(kat_list)/2)
    fig, axes = plt.subplots(row, 2, figsize=(12, 10))
    plt.suptitle('Распределение по категоральным признакам',
                 x=0.5,
                 y=0.92,
                 fontsize=12,
                 fontweight='bold')
    for i, j in enumerate(kat_list):
        axes = axes.flatten()
        sns.countplot(data = df, x=j, ax=axes[i], palette='pastel')
        plt.xticks(rotation=45, ha='right')

# %%
cat_plot(train_job_satisfaction_rate, cat_col_names_train)

# %% [markdown]
# **Корреляционный анализ:**

# %%
num_col_names_train = \
    train_job_satisfaction_rate.loc[:, ~train_job_satisfaction_rate.columns.isin(['id'])]. \
        select_dtypes(include='number').columns.tolist()

# %%
num_col_names_train
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %%
phik_overview_train = \
    phik_matrix(train_job_satisfaction_rate.loc[:, ~train_job_satisfaction_rate.columns.isin(['id'])],
                interval_cols=num_col_names_train, verbose=False)

# %%
plot_correlation_matrix(
    phik_overview_train.values,
    x_labels=phik_overview_train.columns,
    y_labels=phik_overview_train.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# **Вывод по датафрейму train_job_satisfaction_rate**
#
# - количественные признаки не имеют нормальных распределений;
# - на основе исследования категоральных признаков, что можем отметить следующее:
#
# 1) Преобладание сотрудников из департамента sales
# 2) Позиция sinior в минимальном количестве по сравнению с остальными
# 3) Загрузка уровня medium преобладает над остальными
# 4) Самая большая доля - это сотрудники не получившие промоушен в прошлом году
# 5) Большинство сотрудников не нарушали трудовой договор
#
# **Мультиколлинеарность** — явление, при котором наблюдается сильная корреляция больше 0.9, в данном случае ее здесь нет
#
# С целевым признаком больше всего коррелирует признак supervisor_evaluation

# %% [markdown]
# #### Датафрейм test_features

# %% [markdown]
# Для исследовательского анализа добавим в таблицу целевой признак:

# %%
test_features = test_features.merge(test_target_job_satisfaction_rate, on='id', how='left')

# %%
display(test_features.head(5))
display(test_features.shape)
# Out:
#        id       dept   level workload  employment_years last_year_promo
# 0  485046  marketing  junior   medium                 2              no  \
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# 4                   no                      5   40800                   0.75
# (2000, 10)

# %%
test_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 156.4+ KB

# %%
cat_col_names_test
# Out:
# ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
num_col_names_test = \
    test_features.loc[:, ~test_features.columns.isin(['id'])]. \
        select_dtypes(include='number').columns.tolist()

# %%
num_col_names_test
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %% [markdown]
# **Колличественные признаки:**

# %%
test_features[num_col_names_test].describe().T.round(2)
# Out:
#                         count      mean       std       min       25%
# employment_years       2000.0      3.67      2.54      1.00      1.00  \
# supervisor_evaluation  2000.0      3.53      1.00      1.00      3.00
# salary                 2000.0  34066.80  15398.44  12000.00  22800.00
# job_satisfaction_rate  2000.0      0.55      0.22      0.03      0.38
#
#                             50%       75%      max
# employment_years           3.00      6.00     10.0
# supervisor_evaluation      4.00      4.00      5.0
# salary                 30000.00  43200.00  96000.0
# job_satisfaction_rate      0.58      0.72      1.0

# %% [markdown]
# **employment_years:**
# - среднее значение 3.67
# - медиана 3.00
#
# **supervisor_evaluation:**
# - среднее значение 3.53
# - медиана 4.00
#
# **salary:**
# - среднее значение 34,066.80
# - медиана 30,000.00
# - наличие выбросов, вероятно это категория sinior
#
# **job_satisfaction_rate:**
# - среднее значение 0.55
# - медиана 0.58

# %%
hist_plot(test_features, num_col_names_test, 16)

# %% [markdown]
# **Категоральные признаки:**

# %%
cat_col_names_test = test_features.select_dtypes(exclude='number').columns.tolist()

# %%
cat_plot(test_features, cat_col_names_test)

# %%
test_features['workload'].unique()
# Out:
# array(['medium', 'low', 'high', ' '], dtype=object)

# %%
test_features['workload'].value_counts()
# Out:
# workload
# medium    1043
# low        593
# high       363
#              1
# Name: count, dtype: int64

# %% [markdown]
# **Корреляционный анализ:**

# %%
num_col_names_test = \
    test_features.loc[:, ~test_features.columns.isin(['id'])]. \
        select_dtypes(include='number').columns.tolist()

# %%
num_col_names_test
# Out:
# ['employment_years',
#  'supervisor_evaluation',
#  'salary',
#  'job_satisfaction_rate']

# %%
phik_overview_test = \
    phik_matrix(test_features.loc[:, ~test_features.columns.isin(['id'])],
                interval_cols=num_col_names_test, verbose=False)

# %%
plot_correlation_matrix(
    phik_overview_test.values,
    x_labels=phik_overview_test.columns,
    y_labels=phik_overview_test.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# **Вывод по датафрейму test_features**
#
# - количественные признаки не имеют нормальных распределений;
# - на основе исследования категоральных признаков, что можем отметить следующее:
#
# 1) Преобладание сотрудников из департамента sales
# 2) Позиция sinior в минимальном количестве по сравнению с остальными
# 3) Загрузка уровня medium преобладает над остальными
# 4) Самая большая доля - это сотрудника не получившие промоушен в прошлом году
# 5) Большинство сотрудников не нарушали трудовой договор
# 6) Появилось два значение категорий, которые заполнены пробелом, которые планирую игнорировать при кодировании в пайплане с помощью handle_unknown='ignore'
#
# **Мультиколлинеарность** — явление, при котором наблюдается сильная корреляция больше 0.9, в данном случае ее здесь нет
#
# С целевым признаком больше всего коррелирует признак supervisor_evaluation

# %% [markdown]
# ### Подготовка данных

# %%
train_job_satisfaction_rate.head(5)
# Out:
#        id        dept   level workload  employment_years last_year_promo
# 0  155278       sales  junior   medium                 2              no  \
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %% [markdown]
# Перечислим особенности данных:
#
# Три признака: 'dep', 'workload', 'last_year_promo', 'last_year_violations' - нужно кодировать с помощью OneHotEncoder.
#
# Два признака: 'level'  нужно кодировать с помощью OrdinalEncoder.
#
# Количественные признаки: 'employment_years', 'supervisor_evaluation', 'salary' нужно масштабировать.
#
# Выбор лучшей модели будем делать на основе новой метрики — **SMAPE** (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).

# %%
X_train = train_job_satisfaction_rate.drop(['id', 'job_satisfaction_rate'], axis=1)
y_train = train_job_satisfaction_rate['job_satisfaction_rate']

# %%
X_train.columns
# Out:
# Index(['dept', 'level', 'workload', 'employment_years', 'last_year_promo',
#        'last_year_violations', 'supervisor_evaluation', 'salary'],
#       dtype='object')

# %%
# создаём списки с названиями признаков
ohe_columns = ['dept', 'workload', 'last_year_promo', 'last_year_violations']
ord_columns = ['level']
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [(
        'simpleImputer_ohe',
        SimpleImputer(
            missing_values=np.nan,
            strategy='most_frequent'
        )
    ),
     (
         'ohe',
         OneHotEncoder(
             drop='first',
             handle_unknown='ignore',
             sparse=False
         )
     )
    ]
)

# %%
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OHE
ord_pipe = Pipeline(
    [(
        'simpleImputer_before_ord',
        SimpleImputer(
            missing_values=np.nan,
            strategy='most_frequent'
        )
    ),
     (
         'ord',
         OrdinalEncoder(
              categories=[
                  ['junior', 'middle', 'sinior']
                  ], 
                handle_unknown='use_encoded_value',
             unknown_value=np.nan
            )
        ),
     (
         'simpleImputer_after_ord',
         SimpleImputer(
             missing_values=np.nan,
             strategy='most_frequent'
         )
     )
    ]
)

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', StandardScaler(), num_columns)
    ],
    remainder='passthrough'
)

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LinearRegression()
    )
])

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Модели:
#
# **DecisionTreeTreeRegressor()** с гиперпараметрами max_depth от 2 до 20 включительно, min_samples_split от 2 до 20 включительно и max_features от 2 до 20 включительно.
#
# **LinearRegression()**
#
# **Lasso() и Ridge()** с гиперпараметром регулизации alpha: (0, 0.2, 0.25, 0.3, 0.5, 0.75, 0.8, 0.9, 1)
#
# **SVR()** с гиперпараметром сила модели С: (0.01,  0.1, 1, 2, 5, 10) и гиперпараметрами ядер 'rbf','sigmoid', 'linear', 'poly'

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 21),
        'models__min_samples_split': range(2, 21),
        'models__max_features': range(2, 21),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },

    # словарь для модели SVR()
    {
        'models': [SVR()],
        'models__kernel' : ['rbf','sigmoid', 'linear', 'poly'],
        'models__C': [0.01, 0.1, 1, 2, 5, 10],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели LinearRegression()
    {
        'models': [LinearRegression()],  
        
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для моделей Lass(), Ridge()
    {
        'models': [Lasso(random_state = RANDOM_STATE), Ridge(random_state = RANDOM_STATE)],  
        'models__alpha': [0, 0.2, 0.25, 0.3, 0.5, 0.75, 0.8, 0.9, 1],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %% [markdown]
# #### Функция расчета метрики SMAPE

# %% [markdown]
# Функция расчета метрики, чем модель качественнее, тем ниже метрика (greater_is_better = False):

# %%
def smape_func(y_true, y_pred):
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    return np.mean(numerator / denominator) * 100

smape = make_scorer(smape_func, greater_is_better = False)

# %%
randomized_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    cv = 5,
    n_iter=10,
    scoring = smape,
    random_state = RANDOM_STATE,
    n_jobs = -1
)

# %%
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'workload',
#                                                    'last_year_promo',
#                                                    'last_year_violations']),
# ...

# %%
result = pd.DataFrame(randomized_search.cv_results_)
result = result[
    ['rank_test_score', 'param_models', 'mean_test_score', 'params']
    ].sort_values('rank_test_score')

# %%
result
# Out:
#    rank_test_score                                       param_models
# 9                1  DecisionTreeRegressor(max_depth=12, max_featur...  \
# 6                2  DecisionTreeRegressor(max_depth=12, max_featur...
# 0                3  DecisionTreeRegressor(max_depth=12, max_featur...
# 4                4  DecisionTreeRegressor(max_depth=12, max_featur...
# 8                5  DecisionTreeRegressor(max_depth=12, max_featur...
# 5                6  DecisionTreeRegressor(max_depth=12, max_featur...
# 2                7  DecisionTreeRegressor(max_depth=12, max_featur...
# 3                8  DecisionTreeRegressor(max_depth=12, max_featur...
# 1                9  DecisionTreeRegressor(max_depth=12, max_featur...
# 7               10  DecisionTreeRegressor(max_depth=12, max_featur...
#
#    mean_test_score                                             params
# 9       -14.982124  {'preprocessor__num': 'passthrough', 'models__...
# ...

# %% [markdown]
# #### Расчет метрики SMAPE на тестовой выборке

# %%
best_model = randomized_search.best_estimator_['models']
best_model_preprocessor = randomized_search.best_estimator_['preprocessor']

# %%
X_test = test_features.drop(['id', 'job_satisfaction_rate'], axis=1)
y_test = test_features['job_satisfaction_rate']

# %%
X_test_encoded = best_model_preprocessor.transform(X_test)
y_predict_test = best_model.predict(X_test_encoded)

# %%
print ('Метрика лучшей модели на тестовой выборке:', (smape_func(y_test, y_predict_test)).round(2))
# Out:
# Метрика лучшей модели на тестовой выборке: 13.89

# %%
X_train_p = pd.DataFrame(
    best_model_preprocessor.fit_transform(X_train),
    columns=best_model_preprocessor.get_feature_names_out())

# %%
X_test_p = pd.DataFrame(
    best_model_preprocessor.transform(X_test),
    columns=best_model_preprocessor.get_feature_names_out()    
)

# %%
X_train_p.shape
# Out:
# (4000, 12)

# %%
X_test_p.shape
# Out:
# (2000, 12)

# %%
feature_importances = pd.DataFrame(
    {
        'Feature': X_test_p.columns,
        'Importance': best_model.feature_importances_
    }).sort_values('Importance', ascending=False)

plt.figure(figsize=(12, 6))
ax = sns.barplot(data = feature_importances, x='Importance', y='Feature',
                     color='#9BCD9B')
ax.set_title('Важность признаков', fontsize=16)
ax.set_xlabel('Важность (доля)', fontsize=14)
ax.set_ylabel('Признак', fontsize=14)
plt.show()

# %% [markdown]
# #### Вывод по задаче 1

# %% [markdown]
# 1. При выполнении первой задачи удалось обучить модель DecisionTreeRegressor с параметрами (max_depth=12, max_features=11, min_samples_split=8), показавшую результат метрики SMAPE = 13.89, что удовлетворяет условиям задачи SMAPE <= 15
#
# 2. Признаки максимально влияющие на прогноз:
# - num__supervisor_evaluation;
# - num__salary;
# - num__employment_years

# %% [markdown]
# ## Задача 2: предсказание увольнения сотрудника из компании

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# **Тренировочная выборка:**

# %%
file_train_quit_l = '/Users/alexfil/Desktop/Practicum/Проекты/ML SB/train_quit.csv'
file_train_quit_y = 'https://code.s3.yandex.net/datasets/train_quit.csv'

# %%
try:
    train_quit = pd.read_csv(file_train_quit_l, decimal='.', sep=',') 
except:
    train_quit = pd.read_csv(file_train_quit_y, decimal='.', sep=',')

# %%
display(train_quit.head(5))
display(train_quit.shape)
# Out:
#        id        dept   level workload  employment_years last_year_promo
# 0  723290       sales  middle     high                 2              no  \
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
# (4000, 10)

# %% [markdown]
# **Входные признаки тестовой выборки:**

# %%
try:
    test_features = pd.read_csv(file_test_l, decimal='.', sep=',') 
except:
    test_features = pd.read_csv(file_test_y, decimal='.', sep=',')

# %%
display(test_features.head(5))
display(test_features.shape)
# Out:
#        id       dept   level workload  employment_years last_year_promo
# 0  485046  marketing  junior   medium                 2              no  \
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800
# (2000, 9)

# %% [markdown]
# **Целевой признак тестовой выборки:**

# %%
file_target_quit_l = '/Users/alexfil/Desktop/Practicum/Проекты/ML SB/test_target_quit.csv'
file_target_quit_y = 'https://code.s3.yandex.net/datasets/test_target_quit.csv'

# %%
try:
    test_target_quit = pd.read_csv(file_target_quit_l, decimal='.', sep=',') 
except:
    test_target_quit = pd.read_csv(file_target_quit_y, decimal='.', sep=',')

# %%
display(test_target_quit.head(5))
display(test_target_quit.shape)
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes
# (2000, 2)

# %% [markdown]
# #### Вывод по загрузке данных
#
# 1. Загружено 3 датафрейма с разной размерностью отображенной с помощью shape
# 2. При загрузке использованн разделитель значений — запятая, а разделитель десятичных значений — запятая

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# **Поиск дубликатов:**

# %% [markdown]
# Датафрейм test_features обработан ранее, поэтому будем исследовать только train_quit и test_target_quit.

# %%
display(train_quit.duplicated().sum(),
       test_target_quit.duplicated().sum()
       )
# Out:
# 0
# 0

# %% [markdown]
# Исследуем наличие неявных дубликатов:

# %%
cat_col_names_train_quit = train_quit.select_dtypes(exclude='number').columns.tolist()

# %%
for c in cat_col_names_train_quit:
    print(f'Категория: {c}\n\n', train_quit[c].unique(), '\n')
# Out:
# Категория: dept
#
#  ['sales' 'purchasing' 'marketing' 'technology' 'hr']
#
# Категория: level
#
#  ['middle' 'junior' 'sinior']
#
# Категория: workload
#
#  ['high' 'medium' 'low']
#
# Категория: last_year_promo
#
#  ['no' 'yes']
#
# Категория: last_year_violations
#
#  ['no' 'yes']
#
# Категория: quit
#
#  ['no' 'yes']

# %% [markdown]
# **Вывод:** дубликатов нет.

# %% [markdown]
# **Анализ типов данных и пропущенных значений:**

# %%
train_quit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB

# %%
train_quit.isna().sum()
# Out:
# id                       0
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# quit                     0
# dtype: int64

# %%
test_target_quit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# #### Вывод по предобработке данных
#
# 1. Типы данных в датефреймах соответствуют описанию
# 2. Датафрейм test_features содержит пропуски в колонках 'dept и 'level', которые в дальнейшем целесообразно заполнить в пайплане, используя strategy='most_frequent'

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Датафрейм train_quit

# %%
cat_col_names_train_quit
# Out:
# ['dept',
#  'level',
#  'workload',
#  'last_year_promo',
#  'last_year_violations',
#  'quit']

# %%
num_col_names_train_quit = \
    train_quit.loc[:, ~train_quit.columns.isin(['id'])].select_dtypes(include='number').columns.tolist()

# %%
num_col_names_train_quit
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']

# %% [markdown]
# **Количественные признаки:**

# %%
train_quit[num_col_names_train_quit].describe().T.round(2)
# Out:
#                         count      mean       std      min      25%      50%
# employment_years       4000.0      3.70      2.54      1.0      2.0      3.0  \
# supervisor_evaluation  4000.0      3.47      1.00      1.0      3.0      4.0
# salary                 4000.0  33805.80  15152.42  12000.0  22800.0  30000.0
#
#                            75%      max
# employment_years           6.0     10.0
# supervisor_evaluation      4.0      5.0
# salary                 43200.0  96000.0

# %% [markdown]
# **employment_years:**
# - среднее значение 3.70
# - медиана 3.00
#
# **supervisor_evaluation:**
# - среднее значение 3.47
# - медиана 4.00
#
# **salary:**
# - среднее значение 33,805.80
# - медиана 30,000.00
# - наличие выбросов, вероятно это категория sinior

# %%
hist_plot(train_quit, num_col_names_train_quit, 12)

# %% [markdown]
# **Категоральные признаки:**

# %%
def cat_plot_pie(df, kat_list):
    row = math.ceil(len(kat_list)/2)
    fig, ax = plt.subplots(nrows = row, ncols = 2, figsize = (12,12))
    plt.suptitle('Распределение по категоральным признакам',
                 x=0.5,
                 y=0.92,
                 fontsize=12,
                 fontweight='bold')
    k = 0
    for r in range(row):
        for c in range(2):
            ax[r,c].pie(df[kat_list[k]].dropna().value_counts(),
                        labels = df[kat_list[k]].dropna().value_counts().index,
                        startangle=90,
                        autopct = '%1.1f%%',
                        colors=sns.color_palette('Set3')
                        )
            ax[r,c].set_title(kat_list[k])
            k += 1
            if k==len(kat_list):
                break

# %%
cat_plot_pie(train_quit, cat_col_names_train_quit)

# %% [markdown]
# **Корреляционный анализ:**

# %%
num_col_names_train_quit = \
    train_quit.loc[:, ~train_quit.columns.isin(['id'])]. \
        select_dtypes(include='number').columns.tolist()

# %%
num_col_names_train_quit
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']

# %%
phik_overview_train_quit = \
    phik_matrix(train_quit.loc[:, ~train_quit.columns.isin(['id'])],
                interval_cols=num_col_names_train_quit, verbose=False)

# %%
plot_correlation_matrix(
    phik_overview_train_quit.values,
    x_labels=phik_overview_train_quit.columns,
    y_labels=phik_overview_train_quit.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# **Вывод по датафрейму train_quit**
#
# - количественные признаки не имеют нормальных распределений;
# - на основе исследования категоральных признаков, что можем отметить следующее:
#
# 1) Преобладание сотрудников из департамента sales
# 2) Позиция sinior в минимальном количестве по сравнению с остальными
# 3) Загрузка уровня medium преобладает над остальными
# 4) Самая большая доля - это сотрудники не получившие промоушен в прошлом году
# 5) Большинство сотрудников не нарушали трудовой договор
# 6) Доля уволившихся сотрудников 28.2%
#
# **Мультиколлинеарность** — явление, при котором наблюдается сильная корреляция больше 0.9, в данном случае ее здесь нет
#
# С целевым признаком больше всего коррелирует признак salary и employment_years

# %% [markdown]
# #### Датафрейм test_features

# %% [markdown]
# Для исследовательского анализа добавим в таблицу test_features целевой признак

# %%
test_features_quit = test_features.merge(test_target_quit, on='id', how='left')

# %%
display(test_features_quit.head(5))
display(test_features_quit.shape)
# Out:
#        id       dept   level workload  employment_years last_year_promo
# 0  485046  marketing  junior   medium                 2              no  \
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      5   28800   no
# 1                   no                      4   30000   no
# 2                   no                      4   19200   no
# 3                   no                      4   19200   no
# 4                   no                      5   40800   no
# (2000, 10)

# %%
test_features_quit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   quit                   2000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 156.4+ KB

# %%
cat_col_names_test_quit = test_features_quit.select_dtypes(exclude='number').columns.tolist()

# %%
num_col_names_test_quit = \
    test_features_quit.loc[:, ~test_features_quit.columns.isin(['id'])].select_dtypes(include='number').columns.tolist()

# %%
num_col_names_test_quit
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']

# %% [markdown]
# **Количественные признаки:**

# %%
test_features_quit[num_col_names_test_quit].describe().T.round(2)
# Out:
#                         count      mean       std      min      25%      50%
# employment_years       2000.0      3.67      2.54      1.0      1.0      3.0  \
# supervisor_evaluation  2000.0      3.53      1.00      1.0      3.0      4.0
# salary                 2000.0  34066.80  15398.44  12000.0  22800.0  30000.0
#
#                            75%      max
# employment_years           6.0     10.0
# supervisor_evaluation      4.0      5.0
# salary                 43200.0  96000.0

# %% [markdown]
# **employment_years:**
# - среднее значение 3.67
# - медиана 3.00
#
# **supervisor_evaluation:**
# - среднее значение 3.53
# - медиана 4.00
#
# **salary:**
# - среднее значение 34,066.80
# - медиана 30,000.00
# - наличие выбросов, вероятно это категория sinior

# %%
hist_plot(test_features_quit, num_col_names_test_quit, 12)

# %% [markdown]
# **Категоральные признаки:**

# %%
cat_plot_pie(test_features_quit, cat_col_names_test_quit)

# %% [markdown]
# **Корреляционный анализ:**

# %%
num_col_names_test_quit
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']

# %%
phik_overview_test_quit = \
    phik_matrix(test_features_quit.loc[:, ~test_features_quit.columns.isin(['id'])],
                interval_cols=num_col_names_test_quit, verbose=False)

# %%
plot_correlation_matrix(
    phik_overview_test_quit.values,
    x_labels=phik_overview_test_quit.columns,
    y_labels=phik_overview_test_quit.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# **Вывод по датафрейму test_features**
#
# - количественные признаки не имеют нормальных распределений;
# - на основе исследования категоральных признаков, что можем отметить следующее:
#
# 1) Преобладание сотрудников из департамента sales
# 2) Позиция sinior в минимальном количестве по сравнению с остальными
# 3) Загрузка уровня medium преобладает над остальными
# 4) Самая большая доля - это сотрудники не получившие промоушен в прошлом году
# 5) Большинство сотрудников не нарушали трудовой договор
# 6) Доля уволившихся сотрудников 28.2%
#
# **Мультиколлинеарность** — явление, при котором наблюдается сильная корреляция больше 0.9, в данном случае ее здесь нет
#
# С целевым признаком больше всего коррелирует признак salary и employment_years

# %% [markdown]
# #### Портрет «уволившегося сотрудника»

# %% [markdown]
# Вначале исследую train_quit:

# %%
train_quit.head(5)
# Out:
#        id        dept   level workload  employment_years last_year_promo
# 0  723290       sales  middle     high                 2              no  \
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
# разделю на два датафрейма уволившихся и не уволившихся сотрудников
train_quit_yes = train_quit.query('quit == "yes"')
train_quit_no = train_quit.query('quit == "no"')
display(train_quit_yes.shape)
display(train_quit_no.shape)
# Out:
# (1128, 10)
# (2872, 10)

# %%
num_train_quit_yes = train_quit_yes.loc[:, ~train_quit_yes.columns.isin(['id'])]. \
        select_dtypes(include='number').columns.tolist()

# %%
num_train_quit_yes
# Out:
# ['employment_years', 'supervisor_evaluation', 'salary']

# %%
cat_train_quit_yes = train_quit_yes.select_dtypes(exclude='number').columns.tolist()

# %%
cat_train_quit_yes
# Out:
# ['dept',
#  'level',
#  'workload',
#  'last_year_promo',
#  'last_year_violations',
#  'quit']

# %%
hist_plot(train_quit_yes, num_train_quit_yes, 12)

# %%
cat_plot_pie(train_quit_yes, cat_train_quit_yes)

# %% [markdown]
# Проверим гипотезу о том, что зарплата уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании:
#
# - Нулевая гипотеза: средние значения зарплаты двух групп сотрудников равны.
# - Альтернативная гипотеза: среднее значение  зарплаты уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании

# %%
# задаём уровень значимости
alpha = 0.05

quit_no = train_quit_no.sample(n=1128)
results = st.ttest_ind(train_quit_yes['salary'], quit_no['salary'], alternative='less')

display(f'p-value: {results.pvalue}')

# проверяем p-value
if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу')
else:
    display('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# 'p-value: 2.292224041595754e-128'
# 'Отвергаем нулевую гипотезу'

# %% [markdown]
# **Вывод:** полученное значение p-value намного меньше заданного уровня значимости, поэтому можем отвергнуть нулевую гипотезу. Есть основания говорить, что средняя зарплата уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании.

# %% [markdown]
# **Портрет «уволившегося сотрудника»**
#
# 1. Основная часть уволившихся сотрудников **88.9%** - это сотрудники на позиции junior
#
# 2. Пункт 1 также описывает распределение employment_years, которое показывает, что основая часть уволившихся сотрудников проработавших в компании не более 3-х лет
#
# 3. Также это видно на круговой диаграмме - **99.9%** уволивщихся сотрудников, кторые не получили промоушен в прошлом году
#
# 4. Проверка гипотез показывает, что есть основания говорить, что средняя зарплата уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании.
#
# **Уволившийся сотрудник - это позиция junior со стажем в компании менее 3-х лет, не имеющая промоушена и со средней зарплатой меньше, чем у оставшихся сотрудников.**

# %% [markdown]
# #### Уровень удовлетворённости сотрудника работой

# %% [markdown]
# Добавлю данные целевого признака test_target_job_satisfaction_rate в датафрейм test_features_quit

# %%
test_features_quit = test_features_quit.merge(test_target_job_satisfaction_rate, on='id', how='left')

# %%
display(test_features_quit.head(5))
display(test_features_quit.shape)
# Out:
#        id       dept   level workload  employment_years last_year_promo
# 0  485046  marketing  junior   medium                 2              no  \
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      5   28800   no  \
# 1                   no                      4   30000   no
# 2                   no                      4   19200   no
# 3                   no                      4   19200   no
# 4                   no                      5   40800   no
#
#    job_satisfaction_rate
# 0                   0.79
# 1                   0.72
# 2                   0.64
# 3                   0.60
# 4                   0.75
# (2000, 11)

# %%
num_test_quit = test_features_quit.loc[:, ~test_features_quit.columns.isin(['id'])]. \
        select_dtypes(include='number').columns.tolist()

# %%
y_vars = 'job_satisfaction_rate'
g = sns.PairGrid(test_features_quit.loc[:, ~test_features_quit.columns.isin(['id'])],
                 hue='quit', y_vars=y_vars)
plt.suptitle('Зависимость признаков от уровня удовлетворенности',
             x=0.5,
             y=1.2,
             size = 12)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()
pass

# %% [markdown]
# Проверим гипотезу о том, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник
#
# - Нулевая гипотеза: средние значения уровеней удовлетворённости двух групп сотрудников равны.
# - Альтернативная гипотеза: среднее значение  уровеня удовлетворённости уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании

# %%
test_features_quit_yes = test_features_quit.query('quit == "yes"')
test_features_quit_no = test_features_quit.query('quit == "no"')
display(test_features_quit_yes.shape)
display(test_features_quit_no.shape)
# Out:
# (564, 11)
# (1436, 11)

# %%
# задаём уровень значимости
alpha = 0.05

test_quit_no = test_features_quit_no.sample(n=564)
results = st.ttest_ind(
    test_features_quit_yes['job_satisfaction_rate'],
    test_quit_no['job_satisfaction_rate'], alternative='less')

display(f'p-value: {results.pvalue}')

# проверяем p-value
if results.pvalue < alpha:
    display('Отвергаем нулевую гипотезу')
else:
    display('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# 'p-value: 4.002821344789188e-75'
# 'Отвергаем нулевую гипотезу'

# %% [markdown]
# **Вывод:** полученное значение p-value намного меньше заданного уровня значимости, поэтому можем отвергнуть нулевую гипотезу. Есть основания говорить, среднее значение уровня удовлетворённости уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании.

# %% [markdown]
# #### Общий вывод по исследовательскому анализу данных
#
# 1. Основная часть уволившихся сотрудников **88.9%** - это сотрудники на позиции junior
#
# 2. Основая часть уволившихся сотрудников проработавших в компании не более 3-х лет
#
# 3. **99.9%** уволивщихся сотрудников, которые не получили промоушен в прошлом году
#
# 4. Есть основания говорить, что средняя зарплата уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании.
#
# 5. Есть основания говорить, среднее значение уровня удовлетворённости уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании.

# %% [markdown]
# ### Добавление нового входного признака

# %% [markdown]
# Добавим предсказанный лучшей моделью job_satisfaction_rate в тестовую выборку:

# %%
y_predict_df = pd.DataFrame(data = y_predict_test, columns=['job_satisfaction_rate_pred'])

# %%
display(y_predict_df.head(5))
display(y_predict_df.shape)
# Out:
#    job_satisfaction_rate_pred
# 0                    0.883333
# 1                    0.675778
# 2                    0.660000
# 3                    0.666000
# 4                    0.815667
# (2000, 1)

# %%
test_features_quit = test_features_quit.drop(['job_satisfaction_rate'], axis=1)

# %%
test_features_quit = test_features_quit.merge(y_predict_df, left_index=True, right_index=True)

# %%
display(test_features_quit.head(5))
display(test_features_quit.shape)
# Out:
#        id       dept   level workload  employment_years last_year_promo
# 0  485046  marketing  junior   medium                 2              no  \
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      5   28800   no  \
# 1                   no                      4   30000   no
# 2                   no                      4   19200   no
# 3                   no                      4   19200   no
# 4                   no                      5   40800   no
#
#    job_satisfaction_rate_pred
# 0                    0.883333
# 1                    0.675778
# 2                    0.660000
# 3                    0.666000
# ...

# %% [markdown]
# Добавим предсказанный лучшей моделью job_satisfaction_rate в тренировочную выборку:

# %%
train_quit.head(5)
# Out:
#        id        dept   level workload  employment_years last_year_promo
# 0  723290       sales  middle     high                 2              no  \
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
X_quit_encoded = best_model_preprocessor.transform(train_quit)

# %%
train_quit['job_satisfaction_rate_pred'] = best_model.predict(X_quit_encoded)

# %%
display(train_quit.head(5))
display(train_quit.shape)
# Out:
#        id        dept   level workload  employment_years last_year_promo
# 0  723290       sales  middle     high                 2              no  \
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no  \
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
#
#    job_satisfaction_rate_pred
# 0                    0.631087
# 1                    0.822093
# 2                    0.360435
# 3                    0.350000
# ...

# %% [markdown]
# ### Подготовка данных

# %%
X_train_quit = train_quit.drop(['id', 'quit'], axis=1)
y_train_quit = train_quit['quit']

# %%
X_test_quit = test_features_quit.drop(['id', 'quit'], axis=1)
y_test_quit = test_features_quit['quit']

# %% [markdown]
# Закодируем целевой признак числами с помощью кодировщика LabelEncoder:

# %%
label_encoder = LabelEncoder()

# %%
# обучим модель и трансформируйте тренировочную выборку 
y_train_quit = label_encoder.fit_transform(y_train_quit)

# трансформируем тестовую выборку
y_test_quit = label_encoder.transform(y_test_quit)

# %%
print(label_encoder.classes_)
# Out:
# ['no' 'yes']

# %% [markdown]
# Cписки с названиями признаков:

# %%
ohe_columns = ['dept', 'workload', 'last_year_promo', 'last_year_violations']
ord_columns = ['level']
num_columns = ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate_pred']

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final_quit = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# #### Обучение моделей

# %% [markdown]
# Модели:
#
# **DecisionTreeClassifier()** с гиперпараметрами max_depth от 2 до 4 включительно и max_features от 2 до 4 включительно.
#
# **KNeighborsClassifier()** с гиперпараметром n_neighbors от 2 до 19 включительно.
#
# **LogisticRegression(solver='liblinear', penalty='l1')** с гиперпараметром регуляризации С от 1 до 4 включительно.
#
# **SVC(kernel = 'linear')** с гиперпараметром регуляризации С: (0.01,0.1,1,2,5,10)

# %%
param_grid_quit = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC(kernel = 'linear',
                       probability=True
        )],
        'models__C': [0.01,0.1,1,2,5,10],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %%
randomized_search_quit = RandomizedSearchCV(
    pipe_final_quit,
    param_grid_quit,
    cv = 5,
    scoring = 'roc_auc',
    random_state = RANDOM_STATE,
    n_jobs = -1
)

# %%
randomized_search_quit.fit(X_train_quit, y_train_quit)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search_quit.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', randomized_search_quit.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['dept', 'workload',
#                                                    'last_year_promo',
#                                                    'last_year_violations']),
# ...

# %%
best_model_quit = randomized_search_quit.best_estimator_['models']
best_model_preprocessor_quit = randomized_search_quit.best_estimator_['preprocessor']

# %%
X_test_quit_encoded = best_model_preprocessor_quit.transform(X_test_quit)
y_predict_test = best_model_quit.predict(X_test_quit_encoded)

# %% [markdown]
# #### Расчет метрики тестовой выборки

# %%
print(
    f'Метрика ROC-AUC на тестовой выборке: \
    {roc_auc_score(y_test_quit, best_model_quit.predict_proba(X_test_quit_encoded)[::,1])}'
)
# Out:
# Метрика ROC-AUC на тестовой выборке:     0.9199170518975088

# %% [markdown]
# **Метрика тестовой выборки больше 0.91, что соответствует условиям задачи**

# %% [markdown]
# #### Анализ моделей и признаков

# %%
result_quit = pd.DataFrame(randomized_search_quit.cv_results_)
result_quit = result_quit[
    ['rank_test_score', 'param_models', 'mean_test_score', 'params']
    ].sort_values('rank_test_score')

# %%
result_quit
# Out:
#    rank_test_score                                       param_models
# 3                1  LogisticRegression(C=2, penalty='l1', random_s...  \
# 8                2                               SVC(kernel='linear')
# 0                3                             KNeighborsClassifier()
# 7                4                             KNeighborsClassifier()
# 4                5                             KNeighborsClassifier()
# 5                6                             KNeighborsClassifier()
# 6                7                             KNeighborsClassifier()
# 2                8            DecisionTreeClassifier(random_state=42)
# 1                9            DecisionTreeClassifier(random_state=42)
# 9                9            DecisionTreeClassifier(random_state=42)
#
#    mean_test_score                                             params
# 3         0.931150  {'preprocessor__num': StandardScaler(), 'model...
# ...

# %%
X_train_df = pd.DataFrame(
    best_model_preprocessor_quit.fit_transform(X_train_quit),
    columns=best_model_preprocessor_quit.get_feature_names_out())
X_test_df = pd.DataFrame(
    best_model_preprocessor_quit.transform(X_test_quit),
    columns=best_model_preprocessor_quit.get_feature_names_out())

# %%
X_train_df.shape
# Out:
# (4000, 13)

# %%
X_test_df.shape
# Out:
# (2000, 13)

# %%
coefficients = best_model_quit.coef_[0]

# %%
features_names = X_train_df.columns
feature_importance = pd.DataFrame({'Feature': features_names, 'Importance': np.abs(coefficients)})
feature_importance = pd.DataFrame({'Feature': features_names, 'Importance': np.abs(coefficients)})
feature_importance = feature_importance.sort_values('Importance', ascending=True)
sns.set_style('white')
ax = feature_importance.plot(x='Feature',
                             y='Importance',
                             kind='barh',
                             color='#9BCD9B',
                             figsize=(10, 6))
ax.set_title('Важность признаков', fontsize=16)
ax.set_xlabel('Важность (доля)', fontsize=14)
ax.set_ylabel('Признак', fontsize=14)
plt.show()
pass

# %%
explainer =  shap.LinearExplainer(best_model_quit, X_train_df)
shap_values = explainer(X_train_df)
shap.plots.beeswarm(shap_values, max_display=20)

# %% [markdown]
# #### Вывод по подбору и обучению моделей

# %% [markdown]
# **Модель:**
#
# 1. Лучшая модель LogisticRegression, со значением гиперпараметров регуляризации penalty='l1'и С=2
#
# 2. Метрика ROC-AUC лучшей модели на тестовой выборке: 0.92
#
# 3. Метрика ROC-AUC на  кросс-валидации: 0.93
#
# 4. Низкое смещение 7% и низкий разброс 1%, можно сделать вывод, что модель обучена хорошо
#
# **Наиболее важные признаки влияющие на прогноз модели:**
#
# - job_satisfaction_rate_pred;
# - ohe_workload_medium;
# - ohe_last_year_promo_yes;
# - ord_level;
# - num_employment_years;
# - ohe_workload_low;
# - num_salary
#
# **Анализ SHAP значений:**
#
# Чем больше значения признаков: num__employed_years, job_satisfaction_rate_pred и num_salary, тем меньше SHAP‑значения объектов. Если у наблюдения высокое значение этих признаков, то у него высокая вероятность принадлежности к классу 0 (no - сотрудник не уволился), соответсвенно, чем меньше значения этих признаков, тем бельше SHAP-значения и высокая принадлежность к классу 1 (yes - сотрудник уволился)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. Для выполнения поставленных задач заказчиком было предоставленно пять датафреймов, после загрузки и предобработки которых было выявленно:
#
# - типы данных в датефреймах соответствуют описанию;
# - датафреймы train_job_satisfaction_rate и test_features содержат пропуски в колонках 'dept и 'level', которые в дальнейшем целесообразно заполнить в пайплане, используя strategy='most_frequent'
#
# 2. По результатам исследовательского анализа данных можем отметить следующее:
#
# - гистограмма признака salary схожа с распределением Пуасонна с длинным хвостом в сторону высоких зарплат, и медианной в 30,000 близкой к началу координат;
#
# - гистограмма признака job_satisfaction_rate схожа с нормальным распределением с двумя явными скачками в районе 0.4 и 0.7 и медианой 0.56
#
# - в компании больше всего сотрудников из департамента sales (36%);
#
# - позиция junior преобладает по сравнению с остальными (49%;
#
# - загрузка уровня medium преобладает над остальными (53%);
#
# - cамая большая доля - это сотрудники не получившие промоушен в прошлом году (97%);
#
# - большинство сотрудников не нарушали трудовой договор (86%);
#
# - в первой задаче с cцелевым признаком больше всего коррелирует признак supervisor_evaluation;
#
# - во второй задаче с cцелевым признаком больше всего коррелирует признак salary, employment_years и job_satisfaction_rate
#
# 3. Портрет «уволившегося сотрудника
#
# - основная часть уволившихся сотрудников 88.9% - это сотрудники на позиции junior;
#
# - основая часть уволившихся сотрудников проработавших в компании не более 3-х лет;
#
# - 99.9% уволивщихся сотрудников, которые не получили промоушен в прошлом году;
#
# - есть основания говорить, что средняя зарплата уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании;
#
# - есть основания говорить, среднее значение уровня удовлетворённости уволившихся сотрудников меньше, чем у сотрудников оставшихся в компании.
#
# 4. При выполнении первой задачи удалось выявить и обучить лучшую модель DecisionTreeRegressor с параметрами (max_depth=12, max_features=11, min_samples_split=8), показавшую результат метрики SMAPE = 13.89, что удовлетворяет условиям задачи SMAPE <= 15
#
# Признаки максимально влияющие на прогноз:
#
# - num__supervisor_evaluation;
# - num__salary;
# - num__employment_years
#
# 5. При выполнении задачи удалось выявить и обучить лучшую модель LogisticRegression, со значениемиями гиперпараметров регуляризации penalty='l1'и С=2
#
# - метрика ROC-AUC на  кросс-валидации: 0.93
#
# - метрика ROC-AUC лучшей модели на тестовой выборке: 0.92 > 0.91, что соответствует условиям задачи;
#
# - низкое смещение 7% и низкий разброс 1%, можно сделать вывод, что модель обучена хорошо
#
# Наиболее важные признаки влияющие на прогноз модели:
#
# - job_satisfaction_rate_pred;
# - ohe_workload_medium;
# - ohe_last_year_promo_yes;
# - ord_level;
# - num_employment_years;
# - ohe_workload_low;
# - num_salary
#
# Анализ SHAP значений:
#
# Чем больше значения признаков: num__employed_years, job_satisfaction_rate_pred и num_salary, тем меньше SHAP‑значения объектов. Если у наблюдения высокое значение этих признаков, то у него высокая вероятность принадлежности к классу 0 (no - сотрудник не уволился), соответсвенно, чем меньше значения этих признаков, тем бельше SHAP-значения и высокая принадлежность к классу 1 (yes - сотрудник уволился)

# %% [markdown]
# ### Рекомендации для бизнеса

# %% [markdown]
# 1. Для повышения уровня удовлетворенности сотрудников компании необходимо:
#
# - создать прозрачную программу индексации заработной платы;
# - рассмотреть возможность компенсации дополнительных программ (фитнес, мобильная связь, возможность режима удаленной работы);
#
# 2. Для уменьшение количества уволившихся сотрудников необходимо:
#
# - создать прозрачную программу KPI и промоушена на основе достижения установленных показетелей, тем самым мотивируя компеиентных сотрудников на позиции junior развиваться в кампании после 1 года работы;
# - ввести обязательный пересмотр зарплаты для сотрдников проработавших более одного года, при достижении всех поставленных KPI
#
# 3. В текущей реальности удаленный режим работы - это приоритет для многоих сотрудников в независимости от занимаемой позиции, поэтому важная рекомендация - пересмотреть режим работы компании, с целью минимизации работы в офисе.
